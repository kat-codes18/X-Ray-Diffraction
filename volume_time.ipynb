# %%
#only includes data up to frame 55

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def calculate_hcp_lattice_parameters(intensity, two_theta, fwhm, wavelength=1.54, miller_indices=(0, 0, 2)):
    theta = np.radians(two_theta / 2)
    beta = np.radians(fwhm)

    d_spacing = wavelength / (2 * np.sin(theta))

    h, k, l = miller_indices
    a = d_spacing / np.sqrt((4/3) * (h**2 + h*k + k**2) / (h**2 + k**2 + l**2))

    c = a * 1.633

    return a, c

data = []

def add_data_point(time, intensity, two_theta, fwhm, wavelength=1.54, miller_indices=(1, 0, 0)):
    a, c = calculate_hcp_lattice_parameters(intensity, two_theta, fwhm, wavelength, miller_indices)
    volume = (3 * np.sqrt(3) / 2) * a**2 * c  # Volume for HCP structure
    data.append({'time': time, 'lattice_parameter_a': a, 'lattice_parameter_c': c, 'volume': volume})

miller_indices = (1, 0, 0)

N1 = [0.0256, 0.0314, 0.0298, 0.032, 0.0304, 0.0286, 0.0323, 0.0248, 0.0283, 0.0329, 0.0316, 0.0322, 0.0256,
      0.0306, 0.0288, 0.0326, 0.0328, 0.0275, 0.0309, 0.0284, 0.0264, 0.032, 0.0315, 0.0325, 0.0302, 0.018,
      0.0231, 0.0625, 3.65E-09, 1.20E-10, 0.0268, 0.0447, 0.0673, 0.0775, 0.0712, 0.0593, 0.0505, 2.30E-11,
      7.51E-11, 2.39E-10, 2.41E-12, 0.0026, 0.0037, 0.0049, 0.0057, 0.0056, 0.0068, 0.0066, 0.0062, 0.0055,
      0.007, 0.0071, 0.0075]

x1 = [10.9395, 10.9397, 10.9402, 10.9397, 10.9399, 10.94, 10.9398, 10.9396, 10.9398, 10.9402, 10.9403, 10.94,
      10.9397, 10.94, 10.9398, 10.9399, 10.9404, 10.9402, 10.94, 10.9398, 10.9396, 10.9401, 10.9404, 10.9402,
      10.9402, 10.9397, 11.1089, 11.1488, 11.2918, 11.2106, 11.0808, 11.1147, 11.1351, 11.1492, 11.1594,
      11.1679, 11.1745, 10.5164, 10.5164, 10.7909, 10.6997, 10.8737, 10.8788, 10.885, 10.8876, 10.8871,
      10.8921, 10.8973, 10.8888, 10.8978, 10.8982, 10.898, 10.8997]

f1 = [0.022, 0.0222, 0.0224, 0.0218, 0.0218, 0.0223, 0.0216, 0.0221, 0.0223, 0.022, 0.0226, 0.0222, 0.0224,
      0.0221, 0.0223, 0.022, 0.0222, 0.0219, 0.022, 0.0222, 0.0227, 0.0224, 0.0223, 0.0221, 0.022, 0.0227,
      0.0486, 0.052, 0.052, 0.052, 0.038, 0.025, 0.0254, 0.0236, 0.024, 0.0249, 0.0236, 0.052, 0.052, 0.01,
      0.0459, 0.0373, 0.036, 0.048, 0.052, 0.052, 0.052, 0.052, 0.052, 0.0455, 0.052, 0.052, 0.052]

for time, (intensity, two_theta, fwhm) in enumerate(zip(N1, x1, f1)):
    add_data_point(time=time, intensity=intensity, two_theta=two_theta, fwhm=fwhm, miller_indices=miller_indices)

df = pd.DataFrame(data)

plt.plot(df['time'], df['volume'], marker='o')
plt.xlabel('Time (units)')
plt.ylabel('Volume (units³)')
plt.title('Volume Over Time for HCP Structure')
plt.show()

print(df)
# Out:
#     time  lattice_parameter_a  lattice_parameter_c       volume
# 0      0             6.995784            11.424115  1452.603886
# 1      1             6.995656            11.423907  1452.524459
# 2      2             6.995337            11.423386  1452.325920
# 3      3             6.995656            11.423907  1452.524459
# 4      4             6.995529            11.423698  1452.445039
# 5      5             6.995465            11.423594  1452.405331
# 6      6             6.995592            11.423803  1452.484749
# 7      7             6.995720            11.424011  1452.564172
# 8      8             6.995592            11.423803  1452.484749
# 9      9             6.995337            11.423386  1452.325920
# 10    10             6.995274            11.423282  1452.286216
# 11    11             6.995465            11.423594  1452.405331
# 12    12             6.995656            11.423907  1452.524459
# 13    13             6.995465            11.423594  1452.405331
# ...

# %%
#imported data error

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def calculate_hcp_lattice_parameters(intensity, two_theta, fwhm, wavelength=1.54, miller_indices=(1, 0, 0)):


    theta = np.radians(two_theta / 2)
    beta = np.radians(fwhm)


    d_spacing = wavelength / (2 * np.sin(theta))

    h, k, l = miller_indices
    a = d_spacing / np.sqrt((4/3) * (h**2 + h*k + k**2) / (h**2 + k**2 + l**2))


    c = a * 1.633

    return a, c


data = []

def add_data_point(time, intensity, two_theta, fwhm, wavelength=1.54, miller_indices=(1, 0, 0)):
    a, c = calculate_hcp_lattice_parameters(intensity, two_theta, fwhm, wavelength, miller_indices)
    volume = (3 * np.sqrt(3) / 2) * a**2 * c  # Volume for HCP structure
    data.append({'time': time, 'lattice_parameter_a': a, 'lattice_parameter_c': c, 'volume': volume})

miller_indices = (0, 0, 2)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def calculate_hcp_lattice_parameters(intensity, two_theta, fwhm, wavelength=1.54, miller_indices=(1, 0, 0)):

    theta = np.radians(two_theta / 2)
    beta = np.radians(fwhm)


    d_spacing = wavelength / (2 * np.sin(theta))

    h, k, l = miller_indices
    a = d_spacing / np.sqrt((4/3) * (h**2 + h*k + k**2) / (h**2 + k**2 + l**2))


    c = a * 1.633

    return a, c

data = []

def add_data_point(time, intensity, two_theta, fwhm, wavelength=1.54, miller_indices=(1, 0, 0)):
    a, c = calculate_hcp_lattice_parameters(intensity, two_theta, fwhm, wavelength, miller_indices)
    volume = (3 * np.sqrt(3) / 2) * a**2 * c
    data.append({'time': time, 'lattice_parameter_a': a, 'lattice_parameter_c': c, 'volume': volume})


miller_indices = (0, 0, 2)

add_data_point(time=0, intensity=0.0256, two_theta=10.9395, fwhm=0.022, miller_indices=miller_indices)
add_data_point(time=1, intensity=0.0314, two_theta=10.9397, fwhm=0.0222, miller_indices=miller_indices)
add_data_point(time=2, intensity=0.0298, two_theta=10.9402, fwhm=0.0224, miller_indices=miller_indices)
add_data_point(time=3, intensity=0.032, two_theta=10.9397, fwhm=0.0218, miller_indices=miller_indices)
add_data_point(time=4, intensity=0.0304, two_theta=10.9399, fwhm=0.0218, miller_indices=miller_indices)
add_data_point(time=5, intensity=0.0286, two_theta=10.94, fwhm=0.0223, miller_indices=miller_indices)
add_data_point(time=6, intensity=0.0323, two_theta=10.9398, fwhm=0.0216, miller_indices=miller_indices)
add_data_point(time=7, intensity=0.0248, two_theta=10.9396, fwhm=0.0221, miller_indices=miller_indices)
add_data_point(time=8, intensity=0.0283, two_theta=10.9398, fwhm=0.0223, miller_indices=miller_indices)
add_data_point(time=9, intensity=0.0329, two_theta=10.9402, fwhm=0.022, miller_indices=miller_indices)
add_data_point(time=10, intensity=0.0316, two_theta=10.9403, fwhm=0.0226, miller_indices=miller_indices)
add_data_point(time=11, intensity=0.0322, two_theta=10.94, fwhm=0.0222, miller_indices=miller_indices)
add_data_point(time=12, intensity=0.0256, two_theta=10.9397, fwhm=0.0224, miller_indices=miller_indices)
add_data_point(time=13, intensity=0.0306, two_theta=10.94, fwhm=0.0221, miller_indices=miller_indices)
add_data_point(time=14, intensity=0.0288, two_theta=10.9398, fwhm=0.0223, miller_indices=miller_indices)
add_data_point(time=15, intensity=0.0326, two_theta=10.9399, fwhm=0.022, miller_indices=miller_indices)
add_data_point(time=16, intensity=0.0328, two_theta=10.9404, fwhm=0.0222, miller_indices=miller_indices)
add_data_point(time=17, intensity=0.0275, two_theta=10.9402, fwhm=0.0219, miller_indices=miller_indices)
add_data_point(time=18, intensity=0.0309, two_theta=10.94, fwhm=0.022, miller_indices=miller_indices)
add_data_point(time=19, intensity=0.0284, two_theta=10.9398, fwhm=0.0222, miller_indices=miller_indices)
add_data_point(time=20, intensity=0.0264, two_theta=10.9396, fwhm=0.0227, miller_indices=miller_indices)
add_data_point(time=21, intensity=0.032, two_theta=10.9401, fwhm=0.0224, miller_indices=miller_indices)
add_data_point(time=22, intensity=0.0315, two_theta=10.9404, fwhm=0.0223, miller_indices=miller_indices)
add_data_point(time=23, intensity=0.0325, two_theta=10.9402, fwhm=0.0221, miller_indices=miller_indices)
add_data_point(time=24, intensity=0.0302, two_theta=10.9402, fwhm=0.022, miller_indices=miller_indices)
add_data_point(time=25, intensity=0.018, two_theta=10.9397, fwhm=0.0227, miller_indices=miller_indices)
add_data_point(time=26, intensity=0.0231, two_theta=11.1089, fwhm=0.0486, miller_indices=miller_indices)
add_data_point(time=27, intensity=0.0625, two_theta=11.1488, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=28, intensity=3.65E-09, two_theta=11.2918, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=29, intensity=1.20E-10, two_theta=11.2106, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=30, intensity=0.0268, two_theta=11.0808, fwhm=0.038, miller_indices=miller_indices)
add_data_point(time=31, intensity=0.0447, two_theta=11.1147, fwhm=0.025, miller_indices=miller_indices)
add_data_point(time=32, intensity=0.0673, two_theta=11.1351, fwhm=0.0254, miller_indices=miller_indices)
add_data_point(time=33, intensity=0.0775, two_theta=11.1492, fwhm=0.0236, miller_indices=miller_indices)
add_data_point(time=34, intensity=0.0712, two_theta=11.1594, fwhm=0.024, miller_indices=miller_indices)
add_data_point(time=35, intensity=0.0593, two_theta=11.1679, fwhm=0.0249, miller_indices=miller_indices)
add_data_point(time=36, intensity=0.0505, two_theta=11.1745, fwhm=0.0236, miller_indices=miller_indices)
add_data_point(time=37, intensity=2.30E-11, two_theta=10.5164, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=38, intensity=7.51E-11, two_theta=10.5164, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=39, intensity=2.39E-10, two_theta=10.7909, fwhm=0.01, miller_indices=miller_indices)
add_data_point(time=40, intensity=2.41E-12, two_theta=10.6997, fwhm=0.0459, miller_indices=miller_indices)
add_data_point(time=41, intensity=0.0026, two_theta=10.8737, fwhm=0.0373, miller_indices=miller_indices)
add_data_point(time=42, intensity=0.0037, two_theta=10.8788, fwhm=0.036, miller_indices=miller_indices)
add_data_point(time=43, intensity=0.0049, two_theta=10.885, fwhm=0.048, miller_indices=miller_indices)
add_data_point(time=44, intensity=0.0057, two_theta=10.8876, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=45, intensity=0.0056, two_theta=10.8871, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=46, intensity=0.0068, two_theta=10.8921, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=47, intensity=0.0066, two_theta=10.8973, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=48, intensity=0.0062, two_theta=10.8888, fwhm=0.0455, miller_indices=miller_indices)
add_data_point(time=49, intensity=0.0055, two_theta=10.8978, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=50, intensity=0.007, two_theta=10.8982, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=51, intensity=0.0071, two_theta=10.898, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=52, intensity=0.0075, two_theta=10.8997, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=53, intensity=0.0069, two_theta=10.9032, fwhm=0.051, miller_indices=miller_indices)
add_data_point(time=54, intensity=0.0068, two_theta=10.9016, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=55, intensity=0.0067, two_theta=10.9035, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=56, intensity=0.0069, two_theta=10.9079, fwhm=0.0517, miller_indices=miller_indices)
add_data_point(time=57, intensity=0.0075, two_theta=10.9091, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=58, intensity=0.0081, two_theta=10.9141, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=59, intensity=0.0076, two_theta=10.908, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=60, intensity=0.0086, two_theta=10.9147, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=61, intensity=0.0074, two_theta=10.9013, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=62, intensity=0.0082, two_theta=10.9125, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=63, intensity=0.0079, two_theta=10.9168, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=64, intensity=0.0072, two_theta=10.9203, fwhm=0.0518, miller_indices=miller_indices)
add_data_point(time=65, intensity=0.0084, two_theta=10.9175, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=66, intensity=0.0075, two_theta=10.9165, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=67, intensity=0.0075, two_theta=10.9172, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=68, intensity=0.0076, two_theta=10.9216, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=69, intensity=0.0085, two_theta=10.9202, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=70, intensity=0.0076, two_theta=10.9186, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=71, intensity=0.0082, two_theta=10.9199, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=72, intensity=0.0075, two_theta=10.9192, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=73, intensity=0.0078, two_theta=10.9225, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=74, intensity=0.0081, two_theta=10.9204, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=75, intensity=0.0077, two_theta=10.9291, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=76, intensity=0.0076, two_theta=10.9232, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=77, intensity=0.0077, two_theta=10.9259, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=78, intensity=0.0073, two_theta=10.9268, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=79, intensity=0.0081, two_theta=10.9246, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=80, intensity=0.0072, two_theta=10.9249, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=81, intensity=0.0076, two_theta=10.9282, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=82, intensity=0.0082, two_theta=10.9259, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=83, intensity=0.007, two_theta=10.927, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=84, intensity=0.0075, two_theta=10.9326, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=85, intensity=0.0085, two_theta=10.9291, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=86, intensity=0.007, two_theta=10.9261, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=87, intensity=0.007, two_theta=10.9297, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=88, intensity=0.0061, two_theta=10.933, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=89, intensity=0.0079, two_theta=10.9314, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=90, intensity=0.0062, two_theta=10.9298, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=91, intensity=0.0071, two_theta=10.9301, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=92, intensity=0.0071, two_theta=10.9375, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=93, intensity=0.0081, two_theta=10.9346, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=94, intensity=0.0071, two_theta=10.938, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=95, intensity=0.0065, two_theta=10.9303, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=96, intensity=0.0075, two_theta=10.929, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=97, intensity=0.0062, two_theta=10.9332, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=98, intensity=0.0086, two_theta=10.9326, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=99, intensity=0.0077, two_theta=10.9375, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=100, intensity=0.0062, two_theta=10.9319, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=101, intensity=0.0072, two_theta=10.9351, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=102, intensity=0.0062, two_theta=10.9379, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=103, intensity=0.0063, two_theta=10.9303, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=104, intensity=0.008, two_theta=10.9329, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=105, intensity=0.0101, two_theta=10.9332, fwhm=0.052, miller_indices=miller_indices)
add_data_point(time=106, intensity=0.0082, two_theta=10.9371, fwhm=0.052, miller_indices=miller_indices)


# Convert list to DataFrame for easy plotting and manipulation
df = pd.DataFrame(data)

# Plot Volume Over Time
plt.plot(df['time'], df['volume'], marker='o')
plt.xlabel('Time (units)')
plt.ylabel('Volume (units³)')
plt.title('Volume Over Time for HCP Structure')
plt.show()

# Display DataFrame to review stored data
print(df)

df = pd.DataFrame(data)
# Out:
# <ipython-input-6-7b30a972bcad>:47: RuntimeWarning: divide by zero encountered in scalar divide
#   a = d_spacing / np.sqrt((4/3) * (h**2 + h*k + k**2) / (h**2 + k**2 + l**2))
#      time  lattice_parameter_a  lattice_parameter_c  volume
# 0       0                  inf                  inf     inf
# 1       1                  inf                  inf     inf
# 2       2                  inf                  inf     inf
# 3       3                  inf                  inf     inf
# 4       4                  inf                  inf     inf
# ..    ...                  ...                  ...     ...
# 102   102                  inf                  inf     inf
# 103   103                  inf                  inf     inf
# 104   104                  inf                  inf     inf
# 105   105                  inf                  inf     inf
# 106   106                  inf                  inf     inf
#
# [107 rows x 4 columns]
